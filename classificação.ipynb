# %% [markdown]
# # Leitura do dataset

# %%
import pandas as pd

# %%
relacao_alunos = pd.read_excel('Pedido_informacao_sei_23064.030111_2019_10_Versao02.xlsx', 'Relacao_Alunos', header=2)
historico = pd.read_excel('Pedido_informacao_sei_23064.030111_2019_10_Versao02.xlsx', 'Historico', header=2)
questionario = pd.read_excel('Pedido_informacao_sei_23064.030111_2019_10_Versao02.xlsx', 'Questionario_socioEconomico', header=2)

# %%
relacao_alunos.head()
# Out:
#    #      id  ingresso  periodo                  curso  \
# 0  1  +bwsow      2010        1  Ciência Da Computação
# 1  2  f511wn      2010        1  Ciência Da Computação
# 2  3  gwhga8      2010        1  Ciência Da Computação
# 3  4  t5fkjk      2010        1  Ciência Da Computação
# 4  5  3ewz5c      2010        1  Ciência Da Computação
#
#                      forma_de_ingresso                cota   sigla_cota  \
# 0  SISU - Sistema de Seleção Unificada             Cotista      Cotista
# 1  SISU - Sistema de Seleção Unificada  Ampla concorrência  Não cotista
# 2  SISU - Sistema de Seleção Unificada             Cotista      Cotista
# 3  SISU - Sistema de Seleção Unificada  Ampla concorrência  Não cotista
# 4  SISU - Sistema de Seleção Unificada             Cotista      Cotista
#
#               escola  coeficiente  ...  sexo  idade  nascimento        cidade  \
# 0     Escola Pública       0.0222  ...     M     37  30/07/1982  Ponta Grossa
# ...

# %%
historico.head()
# Out:
#    #      id cod_disciplina                       nome  periodo_aluno  \
# 0  1  a+ntz8          SI31C                 ALGORITMOS              1
# 1  2  a+ntz8          SI31F    COMUNICAÇÃO LINGUÍSTICA              1
# 2  3  a+ntz8          SI31G           EMPREENDEDORISMO              1
# 3  4  a+ntz8          SI31E                    ÁLGEBRA              1
# 4  5  a+ntz8          SI31A  FUNDAMENTOS DA COMPUTAÇÃO              1
#
#    ano_lancamento  Per. Lanç.  nota  frequencia  \
# 0            2007           1   0.0        41.0
# 1            2007           1   7.1        97.4
# 2            2007           1   9.0        94.7
# 3            2007           1   0.6        67.8
# 4            2007           1   4.7        84.6
#
#              situacao_disciplina  media_turma  quantidade_alunos_turma
# 0  Reprovado por Nota/Frequência          3.7                       46
# 1   Aprovado por Nota/Frequência          5.2                       40
# ...

# %%
questionario.head()
# Out:
#    #      id  cod_questao                                       pergunta  \
# 0  1  acd5ow            1                                          Sexo:
# 1  2  acd5ow            2  Você tem Necessidades Educacionais Especiais:
# 2  3  acd5ow            3    Em relação à cor da pele você se considera:
# 3  4  acd5ow            4                                  Estado Civil:
# 4  5  acd5ow            5                                  Naturalidade:
#
#          resposta
# 0       Masculino
# 1            Não.
# 2         Branco.
# 3    Solteiro(a).
# 4  Brasileiro(a).

# %%
relacao_alunos.drop(columns=['#'], inplace=True)
historico.drop(columns=['#'], inplace=True)
questionario.drop(columns=['#'], inplace=True)

# %% [markdown]
# # Análise e exploração de dados

# %% [markdown]
# ## Relação_Alunos

# %%
relacao_alunos.head()
# Out:
#        id  ingresso  periodo                  curso  \
# 0  +bwsow      2010        1  Ciência Da Computação
# 1  f511wn      2010        1  Ciência Da Computação
# 2  gwhga8      2010        1  Ciência Da Computação
# 3  t5fkjk      2010        1  Ciência Da Computação
# 4  3ewz5c      2010        1  Ciência Da Computação
#
#                      forma_de_ingresso                cota   sigla_cota  \
# 0  SISU - Sistema de Seleção Unificada             Cotista      Cotista
# 1  SISU - Sistema de Seleção Unificada  Ampla concorrência  Não cotista
# 2  SISU - Sistema de Seleção Unificada             Cotista      Cotista
# 3  SISU - Sistema de Seleção Unificada  Ampla concorrência  Não cotista
# 4  SISU - Sistema de Seleção Unificada             Cotista      Cotista
#
#               escola  coeficiente  vestibular  ...  sexo idade  nascimento  \
# 0     Escola Pública       0.0222         NaN  ...     M    37  30/07/1982
# ...

# %%
# Dados faltantes ou em branco
relacao_alunos.isna().sum()
# Out:
# id                           0
# ingresso                     0
# periodo                      0
# curso                        0
# forma_de_ingresso            0
# cota                         0
# sigla_cota                   0
# escola                       0
# coeficiente                  0
# vestibular                1495
# enem                       448
# sexo                         0
# idade                        0
# nascimento                   0
# cidade                      18
# estado                      18
# etinico                      0
# situacao                     0
# periodo_do_aluno             0
# ano_de_desistencia         494
# periodo_de_desistencia     494
# dtype: int64

# %% [markdown]
# ## Frequência em dados categóricos

# %%
# Balanceado
relacao_alunos.curso.value_counts()
# Out:
# curso
# Curso Superior De Tecnologia Em Análise E Desenvolvimento De Sistemas    998
# Ciência Da Computação                                                    890
# Name: count, dtype: int64

# %%
# Sisu mt mais frequente
relacao_alunos.forma_de_ingresso.value_counts()
# Out:
# forma_de_ingresso
# SISU - Sistema de Seleção Unificada                     1455
# Vestibular                                               375
# Reopção de Curso                                          24
# Transferência                                             16
# Complementação da lista de espera do SISU                 12
# Transferência ex-officio                                   4
# PEC-G - Programa de Estudantes Convênio de Graduação       1
# Aproveitamento de Curso                                    1
# Name: count, dtype: int64

# %%
# Não cotista mt mais frequente, porém aqui talvez a mudança de nomenclatura tenha influenciado.
# talvez seja interessante retrabalhar o dado para apenas "cotista" e "não cotista"
relacao_alunos.sigla_cota.value_counts()
# Out:
# sigla_cota
# Não cotista           933
# Cotista               286
# Sem cotas             165
# Categoria 3           128
# Categoria 1           105
# Categoria L05 (3S)     78
# Categoria 2            49
# Categoria L01 (1S)     48
# Categoria 4            40
# Categoria L06 (4S)     28
# Categoria L02 (2S)     23
# Categoria L13 (3C)      4
# Categoria L10 (2C)      1
# Name: count, dtype: int64

# %%
# Presença maior de pública
relacao_alunos.escola.value_counts()
# Out:
# escola
# Escola Pública       1077
# Escola Particular     779
# -                      32
# Name: count, dtype: int64

# %%
# Grupo de homens é majoritario no conjunto de dados
relacao_alunos.sexo.value_counts()
# Out:
# sexo
# M    1616
# F     272
# Name: count, dtype: int64

# %%
# Ponta Grossa possui a maior parte dos alunos
relacao_alunos.cidade.value_counts()
# Out:
# cidade
# Ponta Grossa       1198
# Curitiba             59
# Castro               56
# Carambeí             33
# Palmeira             26
#                    ...
# Piracaia              1
# Monte Aprazível       1
# Nova Aurora           1
# Araras                1
# Fortaleza             1
# Name: count, Length: 224, dtype: int64

# %%
# consequencia do dado anterior
relacao_alunos.estado.value_counts()
# Out:
# estado
# PR    1525
# SP     278
# MG      17
# SC      16
# MS       5
# RJ       4
# BA       4
# RS       3
# PA       2
# TO       2
# DF       2
# MT       2
# AM       1
# PI       1
# PE       1
# SE       1
# ES       1
# GO       1
# RO       1
# RN       1
# AP       1
# CE       1
# Name: count, dtype: int64

# %%
# Presença muito maior de brancos nominalmente, porém aqui pode ter algum fenômeno de não declaração associado
relacao_alunos.etinico.value_counts()
# Out:
# etinico
# Branca            913
# Não declarado     685
# Parda             193
# Preta              59
# Amarela            32
# Sem informação      5
# Indígena            1
# Name: count, dtype: int64

# %%
# Classe de Desistentes predominante na base.
# Classe "Outros" pode simplificar a vida aqui qnd falamos de qualquer outro q nn seja os quatro primeiros
relacao_alunos.situacao.value_counts()
# Out:
# situacao
# Desistente        930
# Regular           494
# Formado           320
# Jubilado           48
# Transferido        36
# Trancado           34
# Mudou de Curso     18
# Afastado            7
# Expulso             1
# Name: count, dtype: int64

# %% [markdown]
# ## Dados categóricos X situacao

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='curso')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='forma_de_ingresso')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='sigla_cota')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='escola')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='sexo')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='estado')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='etinico')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %% [markdown]
# Consideração: O número de classes no target é muito alto, o que acaba atrapalhando a interpretação dos dados visualmente.
#
# Pensando nisso, no desbalanceamento dos dados,na dificuldade dos modelos de L.M. para interpretar esses dados, e o objetivo deste trabalho em entender as causas de desistência nos cursos de BCC e ADS daa UTFPR, será proposto na próxima seção a discretização da situação em apenas 3 classes: "Formado", "Desistente", "Regular" e "Outros".

# %% [markdown]
# ## Dados categóricos X situacao (retrabalhado)

# %%
# Processamento para deixar apenas Formado, Desistente, Regular e o resto vira Outros
condicao = relacao_alunos['situacao'].isin(['Formado', 'Desistente', 'Regular'])

relacao_alunos['situacao'] = relacao_alunos['situacao'].where(condicao, 'Outros')
relacao_alunos['situacao'].unique().tolist()
# Out:
# ['Desistente', 'Outros', 'Formado', 'Regular']

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='curso', hue='situacao')
# Out:
# <Axes: xlabel='curso', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='curso')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(48,4))
sns.countplot(relacao_alunos, x='forma_de_ingresso', hue='situacao')
# Out:
# <Axes: xlabel='forma_de_ingresso', ylabel='count'>

# %%
plt.figure(figsize=(48,4))
sns.countplot(relacao_alunos, x='situacao', hue='forma_de_ingresso')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(32,4))
sns.countplot(relacao_alunos, x='sigla_cota', hue='situacao')
# Out:
# <Axes: xlabel='sigla_cota', ylabel='count'>

# %%
plt.figure(figsize=(32,4))
sns.countplot(relacao_alunos, x='situacao', hue='sigla_cota')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='escola', hue='situacao')
# Out:
# <Axes: xlabel='escola', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='escola')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='sexo', hue='situacao')
# Out:
# <Axes: xlabel='sexo', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='sexo')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='estado', hue='situacao')
# Out:
# <Axes: xlabel='estado', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='estado')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='etinico', hue='situacao')
# Out:
# <Axes: xlabel='etinico', ylabel='count'>

# %%
plt.figure(figsize=(16,4))
sns.countplot(relacao_alunos, x='situacao', hue='etinico')
# Out:
# <Axes: xlabel='situacao', ylabel='count'>
